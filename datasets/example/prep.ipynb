# %%
prepare_raw_files()
# Out:
# Found: /Users/chstansbury/PycharmProjects/python-arpes/datasets/gating
# ├sheet.xlsx
# └┐
#  ├0
#  ├1
#  ├2
#  ├3
#  ├4
# Encountered Error illegal data type for attribute, must be one of dict_keys(['i2', 'f4', 'u2', 'f8', 'u8', 'i8', 'i1', 'u4', 'i4', 'S1', 'u1']), got b1. Skipping...
# 4edd80b4-48a8-11e8-ac9e-6c40088ef8e6
# 4eddd55a-48a8-11e8-b67f-6c40088ef8e6
# 4ede4970-48a8-11e8-81fc-6c40088ef8e6
# 4edec89a-48a8-11e8-9c4e-6c40088ef8e6
# 4edf6170-48a8-11e8-944c-6c40088ef8e6
# /Users/chstansbury/PycharmProjects/python-arpes/arpes/io.py:207: UserWarning:
#
# Could not fetch cleave information.

# %%
simple_load(1).sum('cycle').spectrum.plot()
# Out:
# WARNING:root:Assuming sort along index
# /Users/chstansbury/PycharmProjects/python-arpes/arpes/io.py:207: UserWarning:
#
# Could not fetch cleave information.
