# %%
import h5py
import arpes.config

import os.path
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
f = h5py.File(os.path.join(arpes.config.DATA_PATH, 'RhSn2/hdf5/RhSn_005.h5'), 'r')

# %%
plt.imshow(f['/RhSn_005'][:,:,20])

# %%
list(f['/RhSn_005'].attrs)
# Out:
# ['IGORWaveType',
#  'IGORWaveNote',
#  'IGORWaveScaling',
#  'IGORWaveUnits',
#  'IGORWaveDimensionLabels']

# %%
scaling = f['/RhSn_005'].attrs['IGORWaveScaling']

# %%
labels = f['/RhSn_005'].attrs['IGORWaveDimensionLabels'][0]
scaling = f['/RhSn_005'].attrs['IGORWaveScaling'][-len(labels)]

# %%
print(list(zip(scaling, labels)))
# Out:
# [(array([ 0.,  0.]), array(['eV', 'phi', 'polar'], dtype=object))]

# %%
print(scaling)
print(labels)
# Out:
# [[  1.59001350e-03  -1.33713496e+00]
#  [  4.68387604e-02  -2.02455319e+01]
#  [  5.00000000e-01  -1.13910000e+01]]
# ['eV' 'phi' 'polar']

# %%
dict(zip(labels, scaling))
# Out:
# {'eV': array([ 0.00159001, -1.33713496]),
#  'phi': array([  0.04683876, -20.24553194]),
#  'polar': array([  0.5  , -11.391])}

# %%
scaling
# Out:
# array([[  0.00000000e+00,   0.00000000e+00],
#        [  1.59001350e-03,  -1.33713496e+00],
#        [  4.68387604e-02,  -2.02455319e+01],
#        [  5.00000000e-01,  -1.13910000e+01]])
