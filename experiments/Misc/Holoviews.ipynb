# %%
import pandas as pd
import numpy as np
import holoviews as hv
import holoviews.util

hv.extension('')
from bokeh.io import output_notebook
# Out:
# WARNING:root:notebook_extension: HoloViews plotly backend could not be imported, ensure plotly is installed.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-19-3f3e6cdb7fab> in <module>()
#       4 import holoviews.util
#       5
# ----> 6 hv.extension('plotly')
#       7 from bokeh.io import output_notebook
#
# ~/anaconda/envs/python_arpes/lib/python3.5/site-packages/param/parameterized.py in __new__(class_, *args, **params)
#    1886         inst = class_.instance()
#    1887         inst._set_name(class_.__name__)
# -> 1888         return inst.__call__(*args,**params)
#    1889
#    1890     def __call__(self,*args,**kw):
#
# ~/anaconda/envs/python_arpes/lib/python3.5/site-packages/holoviews/ipython/__init__.py in __call__(self, *args, **params)
#     107
#     108     def __call__(self, *args, **params):
# --> 109         super(notebook_extension, self).__call__(*args, **params)
#     110         # Abort if IPython not found
#     111         try:
#
# ~/anaconda/envs/python_arpes/lib/python3.5/site-packages/holoviews/util/__init__.py in __call__(self, *args, **params)
#     246
#     247         if selected_backend is None:
# --> 248             raise ImportError('None of the backends could be imported')
#     249         Store.current_backend = selected_backend
#     250
#
# ImportError: None of the backends could be imported

# %%
xs = range(-10, 11)
ys = [100 - el ** 2 for el in xs]

curve = hv.Curve((xs, ys,))
curve
# Out:
# <img src='data:image/png;base64,...' style='max-width:100%; margin: auto; display: block; '/>
